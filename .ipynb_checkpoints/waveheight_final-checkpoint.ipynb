# %% [markdown]
# #Wave Height Predictions with ARIMA

# %% [markdown]
# ## Introduction

# %% [markdown]
# The goal is to use machine learning to build a time-series model that can be used to predict wave height measurements for the selected buoy area. We'll be building an ARIMA model.
#
# The dataset comes from the [National Data Buoy Center](https://www.ndbc.noaa.gov/).
#
# The buoy used for this example is Buoy #[51101](https://www.ndbc.noaa.gov/station_page.php?station=51101), which is located Northwest of Kauai, Hawaii.
#
# Testing.

# %% [markdown]
# ### ARIMA
#
# You can read this article for more info.
# https://medium.com/analytics-vidhya/arima-for-dummies-ba761d59a051

# %% [markdown]
# # Imports and Data

# %% [markdown]
# ## Imports
#
# The below code chunk loads in all your packages and imports, make sure to run this every time you start your session.
#
# Packages include all the tools you need to successfully run all your code and analysis.

# %%
#pip install statsmodels
#pip install pmdarima
#pip intall seaborn
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

from sklearn import linear_model

from pandas import to_datetime
import datetime
from datetime import datetime
import pandas as pd
#import pmdarima as pm
import itertools
import warnings
import matplotlib.pyplot as plt
from matplotlib import pyplot

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_predict

warnings.filterwarnings('ignore')
import seaborn as sns

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## Data
#
# To load in our data, we use the pandas function read_csv to get the data directly from the National Data Buoy Center and are assigning it to the variable called *df1*.
#
# A variable is a place/object where we can store information.

# %%
df1 = pd.read_csv("https://www.ndbc.noaa.gov/view_text_file.php?filename=41049h2017.txt.gz&dir=data/historical/stdmet/"
                  , delimiter= '\s+', index_col=False) # reading in the data

# %%
df_23=pd.read_csv("https://www.ndbc.noaa.gov/view_text_file.php?filename=41049h2023.txt.gz&dir=data/historical/stdmet/"
                  , delimiter= '\s+', index_col=False) # reading in the data
df_22=pd.read_csv("https://www.ndbc.noaa.gov/view_text_file.php?filename=41049h2022.txt.gz&dir=data/historical/stdmet/"
                  , delimiter= '\s+', index_col=False) # reading in the data
df_21=pd.read_csv("https://www.ndbc.noaa.gov/view_text_file.php?filename=41049h2021.txt.gz&dir=data/historical/stdmet/"
                  , delimiter= '\s+', index_col=False) # reading in the data
df_20=pd.read_csv("https://www.ndbc.noaa.gov/view_text_file.php?filename=41049h2020.txt.gz&dir=data/historical/stdmet/"
                  , delimiter= '\s+', index_col=False) # reading in the data

# %%
df1.head() # looking at first 5 rows
# Out:
#     #YY  MM  DD  hh  mm  WDIR WSPD   GST  WVHT    DPD   APD   MWD    PRES  \
# 0   #yr  mo  dy  hr  mn  degT  m/s   m/s     m    sec   sec  degT     hPa
# 1  2016  12  31  23  50    54  8.6  10.5  3.93  11.43  8.29   306  1025.7
# 2  2017  01  01  00  50    55  8.3  11.2  3.56  12.12  7.96   305  1026.2
# 3  2017  01  01  01  50    56  8.2  10.2  3.50  11.43  8.09   298  1026.7
# 4  2017  01  01  02  50    55  7.9   9.8  3.44  12.12  7.90   292  1027.2
#
#    ATMP  WTMP  DEWP   VIS   TIDE
# 0  degC  degC  degC    mi     ft
# 1  20.7  24.3  12.7  99.0  99.00
# 2  20.9  24.3  13.0  99.0  99.00
# 3  20.8  24.3  13.6  99.0  99.00
# 4  20.8  24.3  13.2  99.0  99.00

# %%
print(len(df_23))
print(len(df_22))
print(len(df_21))
print(len(df_20))
# Out:
# 52441
# 52533
# 51510
# 52171

# %% [markdown]
# # Exploring the Data
#
# For this project, the target variable we'll focus on is WVHT (wave height in meters).

# %%
df_23.info() # looking at basic information about your variable
df_22.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52441 entries, 0 to 52440
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   #YY     52441 non-null  object
#  1   MM      52441 non-null  object
#  2   DD      52441 non-null  object
#  3   hh      52441 non-null  object
#  4   mm      52441 non-null  object
#  5   WDIR    52441 non-null  object
#  6   WSPD    52441 non-null  object
#  7   GST     52441 non-null  object
#  8   WVHT    52441 non-null  object
#  9   DPD     52441 non-null  object
#  10  APD     52441 non-null  object
#  11  MWD     52441 non-null  object
#  12  PRES    52441 non-null  object
#  13  ATMP    52441 non-null  object
#  14  WTMP    52441 non-null  object
#  15  DEWP    52441 non-null  object
#  16  VIS     52441 non-null  object
#  17  TIDE    52441 non-null  object
# dtypes: object(18)
# memory usage: 7.2+ MB
# <bound method DataFrame.info of         #YY  MM  DD  hh  mm  WDIR WSPD  GST   WVHT    DPD    APD   MWD  \
# 0       #yr  mo  dy  hr  mn  degT  m/s  m/s      m    sec    sec  degT
# 1      2022  01  01  00  00   285  5.8  7.1  99.00  99.00  99.00   999
# 2      2022  01  01  00  10   286  6.1  7.4  99.00  99.00  99.00   999
# 3      2022  01  01  00  20   289  6.7  8.1  99.00  99.00  99.00   999
# 4      2022  01  01  00  30   287  6.8  8.7  99.00  99.00  99.00   999
# ...     ...  ..  ..  ..  ..   ...  ...  ...    ...    ...    ...   ...
# 52528  2022  12  31  23  10    78    7    9   1.94   7.69   6.01    86
# 52529  2022  12  31  23  20    78  6.7    9     99     99     99   999
# 52530  2022  12  31  23  30    75  6.8  8.7     99     99     99   999
# 52531  2022  12  31  23  40    79  6.6  8.5   1.92     10    6.1   109
# 52532  2022  12  31  23  50    79  6.4  8.2     99     99     99   999
#
#          PRES  ATMP  WTMP  DEWP   VIS   TIDE
# 0         hPa  degC  degC  degC    mi     ft
# 1      1017.9  24.0  24.3  20.8  99.0  99.00
# 2      1018.1  24.0  24.3  20.7  99.0  99.00
# 3      1018.4  24.0  24.3  20.5  99.0  99.00
# 4      1018.2  24.0  24.3  20.6  99.0  99.00
# ...       ...   ...   ...   ...   ...    ...
# 52528  1022.9    23  24.4  18.6    99     99
# 52529    1023    23  24.4  18.5    99     99
# 52530    1023    23  24.5  18.5    99     99
# 52531  1023.1  23.1  24.4  18.5    99     99
# 52532  1023.3  23.1  24.5  18.4    99     99
#
# [52533 rows x 18 columns]>

# %% [markdown]
# From the above information, we learn that the dataset currently has 8,645 rows and 18 columns.

# %%
df1.head() # looking at the first five rows of your data
# Out:
#     #YY  MM  DD  hh  mm  WDIR WSPD   GST  WVHT    DPD   APD   MWD    PRES  \
# 0   #yr  mo  dy  hr  mn  degT  m/s   m/s     m    sec   sec  degT     hPa
# 1  2016  12  31  23  50    54  8.6  10.5  3.93  11.43  8.29   306  1025.7
# 2  2017  01  01  00  50    55  8.3  11.2  3.56  12.12  7.96   305  1026.2
# 3  2017  01  01  01  50    56  8.2  10.2  3.50  11.43  8.09   298  1026.7
# 4  2017  01  01  02  50    55  7.9   9.8  3.44  12.12  7.90   292  1027.2
#
#    ATMP  WTMP  DEWP   VIS   TIDE
# 0  degC  degC  degC    mi     ft
# 1  20.7  24.3  12.7  99.0  99.00
# 2  20.9  24.3  13.0  99.0  99.00
# 3  20.8  24.3  13.6  99.0  99.00
# 4  20.8  24.3  13.2  99.0  99.00

# %% [markdown]
# Let's look to see if we have NA values (missing values) in our dataset.
#
# We're making another variable called *na_values*, to see if any column has NA values.

# %%
na_values = pd.DataFrame(df_20.isna().sum()) # looking at na values
na_values
# Out:
#       0
# #YY   0
# MM    0
# DD    0
# hh    0
# mm    0
# WDIR  0
# WSPD  0
# GST   0
# WVHT  0
# DPD   0
# APD   0
# MWD   0
# PRES  0
# ATMP  0
# WTMP  0
# DEWP  0
# VIS   0
# TIDE  0

# %% [markdown]
# # Data Cleaning
#
# We need to clean our data to help our analysis run smoother and format it properly.

# %% [markdown]
# We'll be deleting the first two rows of our dataset as it just repeats the column names and has a row from 2016, and assigning it to a new variable called df1_clean.

# %%
df1_clean = df_23.iloc[2:] # dropping the first two rows
df1_clean
# Out:
#         #YY  MM  DD  hh  mm WDIR WSPD   GST   WVHT    DPD    APD  MWD    PRES  \
# 2      2023  01  01  00  10   82  6.8   9.7   1.93   9.09   5.88  111  1023.4
# 3      2023  01  01  00  20   75  6.6   8.2  99.00  99.00  99.00  999  1023.4
# 4      2023  01  01  00  30   77  7.0   8.6  99.00  99.00  99.00  999  1023.5
# 5      2023  01  01  00  40   80  6.9   8.9   1.85   6.67   5.94   76  1023.5
# 6      2023  01  01  00  50   76  7.0   8.7  99.00  99.00  99.00  999  1023.6
# ...     ...  ..  ..  ..  ..  ...  ...   ...    ...    ...    ...  ...     ...
# 52436  2023  12  31  23  10  336    9  11.5   2.44     10   7.32  322  1020.5
# 52437  2023  12  31  23  20  337  8.5  10.5     99     99     99  999  1020.4
# 52438  2023  12  31  23  30  337  7.5   9.5     99     99     99  999  1020.4
# 52439  2023  12  31  23  40  343  6.9   8.5   2.57     10   7.61  309  1020.4
# 52440  2023  12  31  23  50  341  6.7   9.1     99     99     99  999  1020.4
#
#        ATMP  WTMP  DEWP   VIS   TIDE
# 2      23.1  24.4  18.9  99.0  99.00
# 3      23.1  24.5  18.9  99.0  99.00
# 4      23.1  24.5  18.9  99.0  99.00
# 5      23.1  24.4  19.0  99.0  99.00
# 6      23.1  24.4  18.9  99.0  99.00
# ...     ...   ...   ...   ...    ...
# 52436  21.5  24.9  19.6    99     99
# 52437  21.2  24.9  19.4    99     99
# 52438  20.9    25  19.4    99     99
# 52439    21    25  19.4    99     99
# 52440  21.2    25  19.6    99     99
#
# [52439 rows x 18 columns]

# %% [markdown]
# As you can see, there are separate columns for year, month, day, hour, and minute. We need to combine these columns in order to create a single datetime column.

# %%
df1_clean = df1_clean.astype({'#YY' : str, 'MM' : str, 'DD' : str, 'hh' : str, 'mm' : str}) # converting these columns to a string data type
df1_clean['Date'] = df1_clean['#YY'] + '-' + df1_clean['MM'] + '-' + df1_clean['DD'] + ' ' + df1_clean['hh'] + ':' + df1_clean['mm'] # combining all the datetime info into a Date column
df1_clean = df1_clean.drop(columns=['#YY','MM','DD','hh','mm']) # deleting the old date and time columns
df1_clean
# Out:
#      WDIR WSPD   GST  WVHT    DPD   APD  MWD    PRES  ATMP  WTMP  DEWP   VIS  \
# 2      55  8.3  11.2  3.56  12.12  7.96  305  1026.2  20.9  24.3  13.0  99.0
# 3      56  8.2  10.2  3.50  11.43  8.09  298  1026.7  20.8  24.3  13.6  99.0
# 4      55  7.9   9.8  3.44  12.12  7.90  292  1027.2  20.8  24.3  13.2  99.0
# 5      60  8.1   9.9  3.72  12.12  8.39  301  1026.8  21.0  24.3  13.4  99.0
# 6      58  8.0   9.9  3.35  11.43  7.97  300  1026.5  21.0  24.3  13.1  99.0
# ...   ...  ...   ...   ...    ...   ...  ...     ...   ...   ...   ...   ...
# 8707  224  5.9   7.6  1.48   9.09  6.07   43  1018.3  24.7  24.9  20.6  99.0
# 8708  227  5.5   6.6  1.41   8.33  5.95  358  1018.3  24.7  24.9  20.3  99.0
# 8709  227  5.9   7.1  1.58   9.09  6.21   69  1018.4  24.5  24.8  20.4  99.0
# 8710  224  6.6   7.6  1.41   8.33  5.90  318  1018.5  24.4  24.8  20.2  99.0
# 8711  228  6.3   7.5  1.50   9.09  6.24   54  1018.9  24.4  24.8  20.2  99.0
#
#        TIDE              Date
# 2     99.00  2017-01-01 00:50
# 3     99.00  2017-01-01 01:50
# 4     99.00  2017-01-01 02:50
# 5     99.00  2017-01-01 03:50
# 6     99.00  2017-01-01 04:50
# ...     ...               ...
# 8707  99.00  2017-12-31 18:50
# 8708  99.00  2017-12-31 19:50
# 8709  99.00  2017-12-31 20:50
# 8710  99.00  2017-12-31 21:50
# 8711  99.00  2017-12-31 22:50
#
# [8710 rows x 14 columns]

# %% [markdown]
# Now we have one column with all the information we need. To move on, we need the data type for that column to be datetime format.

# %%
df1_clean['Date'] = pd.to_datetime(df1_clean['Date'])
df1_clean
# Out:
#      WDIR WSPD   GST  WVHT    DPD   APD  MWD    PRES  ATMP  WTMP  DEWP   VIS  \
# 2      55  8.3  11.2  3.56  12.12  7.96  305  1026.2  20.9  24.3  13.0  99.0
# 3      56  8.2  10.2  3.50  11.43  8.09  298  1026.7  20.8  24.3  13.6  99.0
# 4      55  7.9   9.8  3.44  12.12  7.90  292  1027.2  20.8  24.3  13.2  99.0
# 5      60  8.1   9.9  3.72  12.12  8.39  301  1026.8  21.0  24.3  13.4  99.0
# 6      58  8.0   9.9  3.35  11.43  7.97  300  1026.5  21.0  24.3  13.1  99.0
# ...   ...  ...   ...   ...    ...   ...  ...     ...   ...   ...   ...   ...
# 8707  224  5.9   7.6  1.48   9.09  6.07   43  1018.3  24.7  24.9  20.6  99.0
# 8708  227  5.5   6.6  1.41   8.33  5.95  358  1018.3  24.7  24.9  20.3  99.0
# 8709  227  5.9   7.1  1.58   9.09  6.21   69  1018.4  24.5  24.8  20.4  99.0
# 8710  224  6.6   7.6  1.41   8.33  5.90  318  1018.5  24.4  24.8  20.2  99.0
# 8711  228  6.3   7.5  1.50   9.09  6.24   54  1018.9  24.4  24.8  20.2  99.0
#
#        TIDE                Date
# 2     99.00 2017-01-01 00:50:00
# 3     99.00 2017-01-01 01:50:00
# 4     99.00 2017-01-01 02:50:00
# 5     99.00 2017-01-01 03:50:00
# 6     99.00 2017-01-01 04:50:00
# ...     ...                 ...
# 8707  99.00 2017-12-31 18:50:00
# 8708  99.00 2017-12-31 19:50:00
# 8709  99.00 2017-12-31 20:50:00
# 8710  99.00 2017-12-31 21:50:00
# 8711  99.00 2017-12-31 22:50:00
#
# [8710 rows x 14 columns]

# %%
df1_clean.info() # looking at updated info about our clean dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8710 entries, 2 to 8711
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   WDIR    8710 non-null   object
#  1   WSPD    8710 non-null   object
#  2   GST     8710 non-null   object
#  3   WVHT    8710 non-null   object
#  4   DPD     8710 non-null   object
#  5   APD     8710 non-null   object
#  6   MWD     8710 non-null   object
#  7   PRES    8710 non-null   object
#  8   ATMP    8710 non-null   object
#  9   WTMP    8710 non-null   object
#  10  DEWP    8710 non-null   object
#  11  VIS     8710 non-null   object
#  12  TIDE    8710 non-null   object
#  13  Date    8710 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(13)
# memory usage: 952.8+ KB

# %% [markdown]
# We see that the date column is a datetime data type, and the dataset is now 8,643 rows and 14 columns.

# %% [markdown]
# # ARIMA

# %% [markdown]
# ## ARIMA Prep
#
# In ARIMA, we're only going to be looking at two columns - the date and the WVHT columns (wave height is what we're trying to predict). We're going to select those two columns only and store it in a new variable called *arima_data*.

# %%
arima_data = df1_clean[['Date', 'WVHT']] # selecting columns
arima_data.head() # looking at first five rows of arima_data
# Out:
#                  Date  WVHT
# 2 2017-01-01 00:50:00  3.56
# 3 2017-01-01 01:50:00  3.50
# 4 2017-01-01 02:50:00  3.44
# 5 2017-01-01 03:50:00  3.72
# 6 2017-01-01 04:50:00  3.35

# %% [markdown]
# Next, we want to set the date as the index (the row labels).

# %%
arima_data = arima_data.set_index('Date') # setting date column to index
arima_data
# Out:
#                      WVHT
# Date
# 2017-01-01 00:50:00  3.56
# 2017-01-01 01:50:00  3.50
# 2017-01-01 02:50:00  3.44
# 2017-01-01 03:50:00  3.72
# 2017-01-01 04:50:00  3.35
# ...                   ...
# 2017-12-31 18:50:00  1.48
# 2017-12-31 19:50:00  1.41
# 2017-12-31 20:50:00  1.58
# 2017-12-31 21:50:00  1.41
# 2017-12-31 22:50:00  1.50
#
# [8710 rows x 1 columns]

# %% [markdown]
# Let's try to see what our data looks like.
#
# Our data represents wave heights in our selected buoy area for the year 2017.

# %%
arima_data['WVHT'] = arima_data['WVHT'].astype(float) # changing the datatype for WVHT for a nicer look on the plot
plt.figure(figsize=(10,6)) # setting up the dimentions for our plot
plt.title('2017 Wave Height Measurements (m) for South Bermuda') # setting up a title
plt.plot(arima_data['WVHT']) # plotting our data

# %% [markdown]
# ## Splitting Data for Training and Testing
#
# For supervised machine learning, it's common to split your data for training and testing.
#
# We'll be splitting our data 80-20, meaning 80% of our data will be used to train our ARIMA model while we use the other 20% to test how well our model did.
#
# The training data will be stored in a new variable called *arima_train* while the testing data will be stored in *arima_test*.

# %%
arima_tts = arima_data['WVHT']
arima_train = arima_tts[:int(len(arima_data)*0.8)] # selecting 80% of arima_data for training
arima_test = arima_tts[int(len(arima_data)*0.8):] # selecting the last 20% of data for testing

# %% [markdown]
# Let's double check to make sure our train-test-split went smoothly (that the numbers add up).

# %%
print(len(arima_train)) # printing the length of arima_train
print(len(arima_test)) # printing the length of arima_test
print(len(arima_data)) # arima_train + arima_test should equal arima_data
# Out:
# 6968
# 1742
# 8710

# %% [markdown]
# ## ARIMA Parameters and Testing for Stationarity
#
# ARIMA models have 3 parameters (p, q, d):
#
# - AR = p (found from pacf plot)
# - MA = q (found from acf plot)
# - The number of differencing = d
#
# ------
#
# In order to determine d, we need to figure out if our data is stationary.
#
# Stationary means that your data has a constant mean, variance, and covariance that is independent of time. We can test for stationarity using the Augmented Dickey Fuller (ADF) test.
#
# If your data is **NOT** stationary, we would need to difference it.

# %%
adf_test = adfuller(arima_data['WVHT']) # performing adf test
print('ADF Statistic: ', adf_test[0]) # printing results
print('P-value: ', adf_test[1])
# Out:
# ADF Statistic:  -10.933254489959978
# P-value:  9.702535591501047e-20

# %% [markdown]
# If your p-value is > .05, your time series is not stationary.
#
# If it is < .05, your time series is stationary.
#
# Based on the p-value, our data is *not* stationary.
#
# Because it is not stationary, we need to perform differencing (in order to figure out what the d parameter will be).

# %%
arima_train_diff = arima_train.diff().dropna() # first order differencing

plt.figure(figsize=(10, 6)) # setting up plot size
plt.title('First Order Differencing')
plt.plot(arima_train_diff['WVHT']) # plotting differencing results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# /opt/apps/intel19/python3/3.7.0/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#
# /opt/apps/intel19/python3/3.7.0/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         if res is None:
# --> 649             raise ValueError("Unknown string format:", timestr)
#     650
#
# ValueError: ('Unknown string format:', 'WVHT')
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     602             try:
# --> 603                 key = self._maybe_cast_for_get_loc(key)
#     604             except ValueError as err:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/datetimes.py in _maybe_cast_for_get_loc(self, key)
#     630         # needed to localize naive datetimes
# --> 631         key = Timestamp(key)
#     632         if key.tzinfo is None:
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-61ab0273ffd6> in <module>
#       3 plt.figure(figsize=(10, 6)) # setting up plot size
#       4 plt.title('First Order Differencing')
# ----> 5 plt.plot(arima_train_diff['WVHT']) # plotting differencing results
#
# ~/.local/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~/.local/lib/python3.7/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/datetimes.py in get_loc(self, key, method, tolerance)
#     603                 key = self._maybe_cast_for_get_loc(key)
#     604             except ValueError as err:
# --> 605                 raise KeyError(key) from err
#     606
#     607         elif isinstance(key, timedelta):
#
# KeyError: 'WVHT'

# %% [markdown]
# Since we performed differencing *once*, our d parameter will be equal to 1. Now let's figure out p and q using autocorrelation and partial correlation plots.

# %%
acf_plot = plot_acf(arima_train.diff().dropna()) # autocorrelation plot using training data

# %%
pacf_plot = plot_pacf(arima_train.diff().dropna()) # partial autocorrelation plot on training data

# %% [markdown]
# Based on this plot, we can see that 1 is significant, so p will equal 1.
#
# Based on the acf_plot, it appears to tail off at 2, so we will use 2 for q.
#
# Our parameters for now will be 1,2,1.

# %% [markdown]
# ### Auto Arima
#
# There's a cool function called auto_arima that is a statistical algorithm for determining the optimal parameters for ARIMA.
#
# Running this code might take a minute.

# %%
import pmdarima as pm # importing the package

auto_arima = pm.auto_arima(arima_train, stepwise = False, seasonal = False) # using auto arima on the training data

auto_arima # printing variable
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-7178ab72c48a> in <module>
# ----> 1 import pmdarima as pm # importing the package
#       2
#       3 auto_arima = pm.auto_arima(arima_train, stepwise = False, seasonal = False) # using auto arima on the training data
#       4
#       5 auto_arima # printing variable
#
# ~/.local/lib/python3.7/site-packages/pmdarima/__init__.py in <module>
#      60     from . import compat
#      61     from . import context_managers
# ---> 62     from . import datasets
#      63     from . import decorators
#      64     from . import model_selection
#
# ~/.local/lib/python3.7/site-packages/pmdarima/datasets/__init__.py in <module>
#       3 from .ausbeer import *
#       4 from .austres import *
# ----> 5 from .gasoline import *
#       6 from .heartrate import *
#       7 from .lynx import *
#
# ~/.local/lib/python3.7/site-packages/pmdarima/datasets/gasoline.py in <module>
#       4
#       5 from ..compat.numpy import DTYPE
# ----> 6 from ._base import fetch_from_web_or_disk
#       7
#       8 __all__ = [
#
# ~/.local/lib/python3.7/site-packages/pmdarima/datasets/_base.py in <module>
#       5 import numpy as np
#       6 import pandas as pd
# ----> 7 import urllib3
#       8 import tarfile
#       9
#
# ~/.local/lib/python3.7/site-packages/urllib3/__init__.py in <module>
#      40     elif ssl.OPENSSL_VERSION_INFO < (1, 1, 1):  # Defensive:
#      41         raise ImportError(
# ---> 42             "urllib3 v2.0 only supports OpenSSL 1.1.1+, currently "
#      43             f"the 'ssl' module is compiled with {ssl.OPENSSL_VERSION!r}. "
#      44             "See: https://github.com/urllib3/urllib3/issues/2168"
#
# ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'OpenSSL 1.0.2k-fips  26 Jan 2017'. See: https://github.com/urllib3/urllib3/issues/2168

# %% [markdown]
# Based on these results, the optimal parameters are 1,1,2 (we were close!). We'll use that instead when building out our ARIMA model.

# %% [markdown]
# ## Building the Model
#
# Below we use this code to build and print out the predicted and expected wave heights for the test.
#
# This code might take a couple of minutes.

# %%
# monkey patch around bug in ARIMA class
def __getnewargs__(self):
 return ((self.endog),(self.k_lags, self.k_diff, self.k_ma))
ARIMA.__getnewargs__ = __getnewargs__

# %%
from statsmodels.tsa.arima_model import ARIMAResults

# %%
waveheight_values = arima_data.WVHT
history = [x for x in arima_train]
predictions = list()
for t in range(len(arima_test)):
  model = ARIMA(history, order=(1,1,2)) # input the paramaters here within order=()
  model_fit = model.fit()
  output = model_fit.forecast()
  yhat = output[0]
  predictions.append(yhat)
  obs = arima_test[t]
  history.append(obs)
  print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=1.796850, expected=1.750000
# predicted=1.754011, expected=1.760000
# predicted=1.754371, expected=1.730000
# predicted=1.730851, expected=1.630000
# predicted=1.627568, expected=1.880000
# predicted=1.866789, expected=1.820000
# predicted=1.850376, expected=1.790000
# predicted=1.784595, expected=1.860000
# predicted=1.852471, expected=1.690000
# predicted=1.699790, expected=1.720000
# predicted=1.700493, expected=1.730000
# predicted=1.732343, expected=1.690000
# predicted=1.693710, expected=1.830000
# predicted=1.824291, expected=1.670000
# predicted=1.687012, expected=1.590000
# predicted=1.571999, expected=1.700000
# predicted=1.687906, expected=1.670000
# predicted=1.685379, expected=1.580000
# predicted=1.578309, expected=1.570000
# predicted=1.557500, expected=1.480000
# predicted=1.479424, expected=1.500000
# predicted=1.490674, expected=1.440000
# predicted=1.442726, expected=1.380000
# predicted=1.374250, expected=1.350000
# predicted=1.342663, expected=1.350000
# predicted=1.347103, expected=1.310000
# predicted=1.311061, expected=1.310000
# predicted=1.305581, expected=1.460000
# predicted=1.459159, expected=1.340000
# predicted=1.358961, expected=1.220000
# predicted=1.206409, expected=1.390000
# predicted=1.372665, expected=1.280000
# predicted=1.302342, expected=1.220000
# predicted=1.209292, expected=1.320000
# predicted=1.309734, expected=1.350000
# predicted=1.362999, expected=1.440000
# predicted=1.444373, expected=1.260000
# predicted=1.270005, expected=1.310000
# predicted=1.287868, expected=1.390000
# predicted=1.394346, expected=1.470000
# predicted=1.481749, expected=1.440000
# predicted=1.449134, expected=1.520000
# predicted=1.514674, expected=1.590000
# predicted=1.598074, expected=1.560000
# predicted=1.569090, expected=1.400000
# predicted=1.396252, expected=1.480000
# predicted=1.459565, expected=1.410000
# predicted=1.420247, expected=1.450000
# predicted=1.443941, expected=1.310000
# predicted=1.314188, expected=1.540000
# predicted=1.523012, expected=1.630000
# predicted=1.656350, expected=1.620000
# predicted=1.632762, expected=1.830000
# predicted=1.824701, expected=1.660000
# predicted=1.684223, expected=1.650000
# predicted=1.630507, expected=1.640000
# predicted=1.635960, expected=1.660000
# predicted=1.661028, expected=1.610000
# predicted=1.613093, expected=1.440000
# predicted=1.434754, expected=1.500000
# predicted=1.479156, expected=1.320000
# predicted=1.328586, expected=1.360000
# predicted=1.340897, expected=1.350000
# predicted=1.353762, expected=1.360000
# predicted=1.361038, expected=1.340000
# predicted=1.340838, expected=1.430000
# predicted=1.427073, expected=1.360000
# predicted=1.370927, expected=1.430000
# predicted=1.395841, expected=1.570000
# predicted=1.576911, expected=2.190000
# ...
# predicted=3.308695, expected=3.270000
# predicted=3.337288, expected=3.170000
# predicted=3.166311, expected=3.740000
# predicted=3.718644, expected=3.810000
# predicted=3.873180, expected=3.770000
# predicted=3.780331, expected=3.800000
# predicted=3.788481, expected=3.700000
# predicted=3.702673, expected=3.650000
# predicted=3.640467, expected=3.400000
# predicted=3.395400, expected=3.630000
# predicted=3.602248, expected=3.640000
# predicted=3.665847, expected=3.560000
# predicted=3.564605, expected=3.540000
# predicted=3.528420, expected=3.760000
# predicted=3.756168, expected=3.140000
# predicted=3.168660, expected=3.070000
# predicted=3.002512, expected=3.080000
# predicted=3.069015, expected=3.160000
# predicted=3.168094, expected=3.230000
# predicted=3.239672, expected=3.330000
# predicted=3.336329, expected=3.070000
# predicted=3.081271, expected=2.850000
# predicted=2.821839, expected=2.820000
# predicted=2.794686, expected=2.900000
# predicted=2.899373, expected=2.760000
# predicted=2.772257, expected=2.640000
# predicted=2.625334, expected=2.390000
# predicted=2.376693, expected=2.520000
# predicted=2.493507, expected=2.490000
# predicted=2.505835, expected=2.330000
# predicted=2.330436, expected=2.270000
# predicted=2.251047, expected=2.020000
# predicted=2.014575, expected=2.160000
# predicted=2.133923, expected=1.860000
# predicted=1.877478, expected=2.180000
# predicted=2.148232, expected=2.140000
# predicted=2.173518, expected=2.110000
# predicted=2.109293, expected=2.080000
# predicted=2.073143, expected=2.050000
# predicted=2.046910, expected=1.720000
# predicted=1.719121, expected=1.820000
# predicted=1.783431, expected=1.960000
# predicted=1.970366, expected=1.840000
# predicted=1.860024, expected=1.780000
# predicted=1.765993, expected=2.020000
# predicted=2.010000, expected=1.920000
# predicted=1.948374, expected=1.750000
# predicted=1.741025, expected=1.930000
# predicted=1.907386, expected=1.970000
# predicted=1.990444, expected=1.870000
# predicted=1.877354, expected=1.730000
# predicted=1.717569, expected=1.970000
# predicted=1.952719, expected=1.720000
# predicted=1.748811, expected=1.780000
# predicted=1.754313, expected=1.700000
# predicted=1.703769, expected=1.770000
# predicted=1.763719, expected=1.820000
# predicted=1.826978, expected=1.710000
# predicted=1.716711, expected=1.600000
# predicted=1.587786, expected=1.810000
# predicted=1.796199, expected=1.560000
# predicted=1.585502, expected=1.640000
# predicted=1.613829, expected=1.720000
# predicted=1.725509, expected=1.620000
# predicted=1.632096, expected=1.780000
# predicted=1.767689, expected=1.680000
# predicted=1.696647, expected=1.650000
# predicted=1.640595, expected=1.580000
# predicted=1.575239, expected=1.680000
# predicted=1.672871, expected=1.830000
# predicted=1.840678, expected=1.780000
# predicted=1.797424, expected=1.780000
# predicted=1.773403, expected=2.110000
# predicted=2.106436, expected=2.040000
# predicted=2.077058, expected=2.280000
# predicted=2.271582, expected=2.090000
# predicted=2.113139, expected=2.000000
# predicted=1.980628, expected=1.970000
# predicted=1.957748, expected=2.050000
# predicted=2.048417, expected=2.110000
# predicted=2.119779, expected=2.120000
# predicted=2.126696, expected=2.360000
# predicted=2.358830, expected=2.460000
# predicted=1.878169, expected=1.780000
# predicted=1.775637, expected=1.640000
# predicted=1.629864, expected=2.040000
# predicted=2.023004, expected=1.860000
# predicted=1.906133, expected=1.760000
# predicted=1.742640, expected=1.740000
# predicted=1.724009, expected=2.020000
# predicted=2.018260, expected=1.710000
# predicted=1.744050, expected=1.720000
# predicted=1.686183, expected=1.620000
# predicted=1.617814, expected=1.610000
# predicted=1.602784, expected=1.710000
# predicted=1.708623, expected=1.510000
# predicted=1.522786, expected=1.630000
# predicted=1.607591, expected=1.480000
# predicted=1.492516, expected=1.690000
# predicted=1.674914, expected=1.570000
# predicted=1.592330, expected=1.710000
# predicted=1.697761, expected=1.620000
# predicted=1.633409, expected=1.580000
# predicted=1.571653, expected=1.690000
# predicted=1.683544, expected=1.580000
# predicted=1.593593, expected=1.770000
# predicted=1.757632, expected=2.100000
# predicted=2.117736, expected=2.230000
# predicted=2.267111, expected=2.230000
# predicted=2.242426, expected=2.650000
# predicted=2.643783, expected=2.710000
# predicted=2.754659, expected=3.010000
# predicted=3.015887, expected=2.860000
# predicted=2.889037, expected=2.780000
# predicted=2.763202, expected=2.960000
# predicted=2.947015, expected=2.840000
# predicted=2.862351, expected=2.730000
# predicted=2.718773, expected=2.850000
# predicted=2.834767, expected=2.680000
# predicted=2.695343, expected=2.820000
# predicted=2.802200, expected=2.430000
# predicted=2.445767, expected=2.660000
# predicted=2.617570, expected=2.550000
# predicted=2.574281, expected=2.610000
# predicted=2.602232, expected=2.420000
# predicted=2.424923, expected=2.370000
# predicted=2.350017, expected=2.430000
# predicted=2.423566, expected=2.600000
# predicted=2.607999, expected=2.520000
# predicted=2.539993, expected=2.690000
# predicted=2.679390, expected=2.410000
# predicted=2.428085, expected=2.220000
# predicted=2.191075, expected=2.210000
# predicted=2.186903, expected=2.320000
# predicted=2.321499, expected=2.210000
# predicted=2.225317, expected=2.260000
# predicted=2.247403, expected=1.990000
# predicted=1.995205, expected=2.180000
# predicted=2.150454, expected=1.990000
# predicted=2.011481, expected=2.090000
# predicted=2.071669, expected=1.900000
# predicted=1.909686, expected=2.080000
# predicted=2.059964, expected=1.810000
# predicted=1.830360, expected=1.680000
# predicted=1.652817, expected=1.720000
# predicted=1.702999, expected=1.630000
# predicted=1.637925, expected=1.630000
# predicted=1.621873, expected=1.580000
# predicted=1.579359, expected=1.670000
# predicted=1.664870, expected=1.540000
# predicted=1.550765, expected=1.540000
# predicted=1.526089, expected=1.520000
# predicted=1.518880, expected=1.650000
# predicted=1.648656, expected=1.540000
# predicted=1.555182, expected=1.550000
# predicted=1.537855, expected=1.530000
# predicted=1.529506, expected=1.450000
# predicted=1.449532, expected=1.520000
# predicted=1.510775, expected=1.320000
# predicted=1.328871, expected=1.340000
# predicted=1.318621, expected=1.350000
# predicted=1.351159, expected=1.480000
# predicted=1.482839, expected=1.410000
# predicted=1.424735, expected=1.580000
# predicted=1.571021, expected=1.410000
# predicted=1.428197, expected=1.500000

# %%
import csv
with open('predictions.csv', 'w', newline='') as file:
    # Step 4: Using csv.writer to write the list to the CSV file
    writer = csv.writer(file)
    writer.writerow(predictions) # Use writerow for single list

# %%
# save model
model_fit.save('model.pkl')
# load model
loaded = ARIMAResults.load('model.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-f4c1e403d918> in <module>
#       1 # save model
# ----> 2 model_fit.save('model.pkl')
#       3 # load model
#       4 loaded = ARIMAResults.load('model.pkl')
#
# ~/.local/lib/python3.7/site-packages/statsmodels/base/wrapper.py in save(self, fname, remove_data)
#      69             self.remove_data()
#      70
# ---> 71         save_pickle(self, fname)
#      72
#      73     @classmethod
#
# ~/.local/lib/python3.7/site-packages/statsmodels/iolib/smpickle.py in save_pickle(obj, fname)
#      15
#      16     with get_file_obj(fname, "wb") as fout:
# ---> 17         pickle.dump(obj, fout, protocol=-1)
#      18
#      19
#
# <ipython-input-19-14edbd44259e> in __getnewargs__(self)
#       1 # monkey patch around bug in ARIMA class
#       2 def __getnewargs__(self):
# ----> 3  return ((self.endog),(self.k_lags, self.k_diff, self.k_ma))
#       4 ARIMA.__getnewargs__ = __getnewargs__
#
# AttributeError: 'ARIMA' object has no attribute 'k_lags'

# %% [markdown]
# ## Visualization
#
# After the model completes its forecast, create a plot to visualize the difference between the predicted values and expected vales for wave heights.

# %%
test_x = arima_test.index # creating an index variable so that it's the dates

plt.figure (figsize=(10,6)) # setting up the plot size

plt.plot(test_x, arima_test, label='Expected') # plotting expected values
plt.plot(test_x, predictions, color='red', label='Prediction') # plotting predicted values
plt.xlabel('Date')
plt.ylabel('Wave Height')
plt.title('Difference Between Predicted and Actual Wave Heights')
plt.legend() # adding a legend to the plot

plt.xticks(rotation=45) # rotating the x labels for better visualization

plt.show()

# %%
import plotly.graph_objects as go
# Assuming arima_train, arima_test, and predictions are Pandas Series with datetime index
train_x = arima_train.index
test_x = arima_test.index
fig = go.Figure()
# Add traces for training, expected, and predicted values
fig.add_trace(go.Scatter(x=train_x, y=arima_train, mode='lines', name='Training', line=dict(color='green')))
fig.add_trace(go.Scatter(x=test_x, y=arima_test, mode='lines', name='Expected'))
fig.add_trace(go.Scatter(x=test_x, y=predictions, mode='lines', name='Prediction', line=dict(color='red')))
# Update layout for better visualization
fig.update_layout(
    title='Difference Between Predicted and Actual Wave Heights',
    xaxis_title='Date',
    yaxis_title='Wave Height',
    legend_title='Legend',
    xaxis=dict(tickangle=45),
    autosize=False,
    width=1000,
    height=600,
)
# Show the plot
fig.show()

# %% [markdown]
# ## Model Evaluation
#
# In machine learning, there are different ways to evaluate how well your model performed depending on what type of model you use.
#
# For this project, we'll use mean absolute error and root squared value to determine how well our model did.
#
# You can review this [resource](https://www.analyticsvidhya.com/blog/2021/10/evaluation-metric-for-regression-models/) to understand the metrics better.

# %%
mae = mean_absolute_error(arima_test, predictions) # calculating mean absolute error
r_sq = r2_score(arima_test, predictions) # calculating root squared value
print('Test MAE: ', mae)
print('Test R^2: ', r_sq)

# %% [markdown]
# Based on these results and the visualization, this model did pretty good!

# %% [markdown]
# ## Forecasting Values for the Future
#
# Now that we've fitted, trained, tested, and evaluated our model, let's try to forecast future values.
